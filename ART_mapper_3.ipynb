# %%
import os
import re
import sys
import time
import nltk
import openpyxl
import collections
import numpy as np
import pandas as pd
import pandas.io.formats.excel
from sklearn import preprocessing
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.preprocessing import label_binarize
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def read_data(path):
    data = pd.read_excel(path)
    return data

# %%
def get_service_name(data):
    service_name = pd.DataFrame(data['SERVICE_NAME'])
    return service_name

# %%
def get_data_by_service_type(data, types):
    data = data[data['SERVICE_TYPE'].isin(types)]
    data.reset_index(inplace=True,drop=True)
    return data

# %%
def get_standards_path():
    paths = []
    for file in os.listdir("Standards"):
        paths.append(os.path.join("Standards", file))
    return paths

# %%
def read_standards(paths):
    stds = []
    for path in paths:
        stds.append(pd.read_excel(path))
    return stds

# %%
def get_providers_path():
    paths = []
    for file in os.listdir("Providers"):
        paths.append(os.path.join("Providers", file))
    return paths

# %%
def create_document(DF1,col_index): #DF1 is the DF to be preprocessed #col_index is the number of the describtion column (int)
    stopWords = set(stopwords.words('english'))
    uselessWords = ['intended','for','use','helps','to','provide','all','detection','of']
    # Making A copy to prevent change to the original DF as it is needd subsequently
    DF = DF1.copy()
    # Insuring string type for the wanted col
    DF[DF.columns[col_index]] = DF[DF.columns[col_index]].astype(str)
    # Removing all newline and replacing it with space
    DF[DF.columns[col_index]] = DF[DF.columns[col_index]].str.replace('\n',' ')
    #Replacing all non alphanumeric in both english and arabic by space
    #DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x: re.sub('[^A-Za-z0-9]+', ' ', x))
    #Separating camel case with space
    #DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x: re.sub(r"([a-z])([A-Z])", r"\1 \2", x))
    #lowercasing all describtions
    DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x:" ".join(x.lower() for x in x.split()))
    #removing stop words
    DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x:" ".join (word for word in x.split() if word not in stopWords))
    #removing useless words
    DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x:" ".join(word for word in x.split() if word not in uselessWords))
    #DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x:''.join(i for i in x if not i.isdigit()))
    #In case a med dict present (referring the medical abbreviation to its origin) this line return the abbreviation to origin
    ## DF_document.document = DF_document.document.apply(lambda x: " ".join(med_dict(word) for word in x.split()) )
    #Counting all Words that occur either in very low freq or very high and removing them (Threshhold must be configured)
    ## freq = pd.Series(' '.join(DF[DF.columns[col_index]]).split()).value_counts()[:50]
    ## DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x: " ".join(x for x in x.split() if  x not in freq.index))
    ## freq = pd.Series(' '.join(DF[DF.columns[col_index]]).split()).value_counts()[-1034:]
    ## DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x: " ".join(x for x in x.split() if x not in freq.index))
    #Defining a stemmer and stemming all words in the description
    #st = PorterStemmer()
    #DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
    #DF[DF.columns[col_index]] = DF[DF.columns[col_index]].apply(lambda x: "" if x.isdigit() == True else x)
    return DF

# %%
def concat(service_name,standards):
    DF = pd.concat(objs = [service_name,standards])
    #DF = DF.apply(lambda x: ''.join(i for i in x if not i.isdigit()))
    return DF

# %%
def create_vectorizer(df,service_name,standard):
    stopWords = stopwords.words('english')
    tfidf = TfidfVectorizer(
                analyzer = "word",  
                tokenizer = None,  
                preprocessor = None, 
                stop_words = None,  
                max_features = None,
                token_pattern = r"(?u)\b\w+\b")
    
    tfidf.fit(df)
    tfref = tfidf.transform(standard)
    tfdata = tfidf.transform(service_name)
    return tfref,tfdata

# %%
def find_similar(tfidf_data,tfidf_ref, index, rank = 0):
    #multiplying the 2 matrix to find the cosine similarity
    cosine_similarities = linear_kernel(tfidf_data[index:index+1], tfidf_ref[:]).flatten()
    #getting the most similar index
    highest_ind = cosine_similarities.argsort()[::-1][rank]
    #return the index along with its similarity
    return highest_ind, cosine_similarities[highest_ind]

# %%
def get_similarity(data,tfdata,tfref):
    result = pd.DataFrame(columns = ['Serv','cpt','Sim','Num'])
    resultAll = pd.DataFrame(columns = ['Serv','cpt','Sim','Num'])
    for i in range(len(data)):
        for j in range(0,1):
            index, simlarity = find_similar(tfdata, tfref, i, j)
            result.loc[i] = [i, index, simlarity, j]
            resultAll = resultAll.append(result)
            result.drop(result.index, inplace = True)
    return resultAll

# %%
def get_max_results(data,result_ACHI,result_LOINC,result_SFDA):
    df = pd.DataFrame(columns=['Serv','cpt','Sim','Num','MAPPED_CODE'])
    for i in range(len(result_ACHI)):
        sims=[result_ACHI.iloc[i,2], result_LOINC.iloc[i,2]]
        if data.iloc[i,5] != 'Lab' and data.iloc[i,5] != 'Other Medical Services':
            df.loc[i] = result_ACHI.iloc[i].to_list() + ['ACHI']
        elif data.iloc[i,5] == 'Other Medical Services':
            df.loc[i] = result_SFDA.iloc[i].to_list() + ['SFDA']
        elif data.iloc[i,5] == 'Lab':
            df.loc[i] = result_LOINC.iloc[i].to_list() + ['LOINC']
    return df

# %%
def do_map(data,result,ACHI,LOINC,SFDA):
    data['MAPPED_CODE'] = result['MAPPED_CODE']
    for i in range(len(data)):
        if result.iloc[i,4] == 'ACHI':
            data.loc[i, 'UNIFIED_CODE'] = ACHI.iloc[int(result.iloc[i,1]),0]
            data.loc[i, 'UNIFIED_CODE_DESCRIPTION'] = ACHI.iloc[int(result.iloc[i,1]),3]
        elif result.iloc[i,4] == 'LOINC':
            data.loc[i, 'UNIFIED_CODE'] = LOINC.iloc[int(result.iloc[i,1]),0]
            data.loc[i, 'UNIFIED_CODE_DESCRIPTION'] = LOINC.iloc[int(result.iloc[i,1]),7]
        else:
            data.loc[i, 'UNIFIED_CODE'] = SFDA.iloc[int(result.iloc[i,1]),0]
            data.loc[i, 'UNIFIED_CODE_DESCRIPTION'] = SFDA.iloc[int(result.iloc[i,1]),3]
    data['Similarity'] = result['Sim']
    return data

# %%
def filter_by_similarity(data, thresh):
    data.loc[data['Similarity'] <= thresh, ['UNIFIED_CODE','UNIFIED_CODE_DESCRIPTION','MAPPED_CODE']] = "Couldn't Be Mapped"
    return data

# %%
def files_mapping(data_path):
    data = read_data(data_path)
    data = get_data_by_service_type(data, ['Lab','Diagnosis Procedure','Dental','Diagnostic Procedures','Other Medical Services','Package Deal','Physiotherapy','Radiology'])
    ACHI, LOINC, SFDA = read_standards(get_standards_path())
    service_name = get_service_name(data)
    
    ACHI_processed = create_document(ACHI,3)
    LOINC_processed = create_document(LOINC,7)
    SFDA_processed = create_document(SFDA,3)
    data_processed = create_document(service_name,0)
    
    if len(data_processed) > 0:
        tfref_ACHI,tfdata_ACHI = create_vectorizer(concat(data_processed['SERVICE_NAME'],ACHI_processed['ascii_desc']),data_processed['SERVICE_NAME'],ACHI_processed['ascii_desc'])
        tfref_LOINC,tfdata_LOINC = create_vectorizer(concat(data_processed['SERVICE_NAME'],LOINC_processed['LONG_COMMON_NAME']),data_processed['SERVICE_NAME'],LOINC_processed['LONG_COMMON_NAME'])
        tfred_SFDA ,tfdata_SFDA = create_vectorizer(concat(data_processed['SERVICE_NAME'],SFDA_processed['intended_purpose']),data_processed['SERVICE_NAME'],SFDA_processed['intended_purpose'])
        resultAll_ACHI = get_similarity(data,tfdata_ACHI,tfref_ACHI)
        resultAll_LOINC = get_similarity(data,tfdata_LOINC,tfref_LOINC)
        resultAll_SFDA = get_similarity(data,tfdata_SFDA,tfred_SFDA)
        AllResult = get_max_results(data,resultAll_ACHI,resultAll_LOINC,resultAll_SFDA)
        AllResult = do_map(data,AllResult,ACHI,LOINC,SFDA)
        AllResult = filter_by_similarity(AllResult, 0.0)
        AllResult = swap_columns(AllResult)
    else:
        AllResult = []

    return AllResult

# %%
def swap_columns(data):
    columnsTitles = data.columns.to_list()
    result = data.reindex(columns=columnsTitles[:5]+['UNIFIED_CODE_DESCRIPTION']+['UNIFIED_CODE']+['SERVICE_TYPE']+['MAPPED_CODE']+['Similarity'])
    return result

# %%
def export_excel(path):
    writer = pd.ExcelWriter(path,engine='openpyxl')
    writer.book = openpyxl.load_workbook(path)
    
    pandas.io.formats.excel.ExcelFormatter.header_style = None
    
    result["Y/N"] = np.nan
    result["Doctor's Recommended Code"] = np.nan
    result["Doctor's Recommended Code Description"] = np.nan
    result[(result.MAPPED_CODE == 'ACHI') | ((result.SERVICE_TYPE != 'Lab') & (result.SERVICE_TYPE != 'Other Medical Services'))].to_excel(writer,sheet_name='ACHI',index=False)
    result[(result.MAPPED_CODE == 'LOINC')| (result.SERVICE_TYPE == 'Lab')].to_excel(writer,sheet_name='LOINC',index=False)
    result[(result.MAPPED_CODE == 'SFDA') | (result.SERVICE_TYPE == 'Other Medical Services')].to_excel(writer,sheet_name='SFDA',index=False)
    
    for i, sheetname in enumerate(writer.book.sheetnames):
        worksheet = writer.book[sheetname]
        mediumStyle = openpyxl.worksheet.table.TableStyleInfo(name='TableStyleMedium2',showRowStripes=True)
        table = openpyxl.worksheet.table.Table(ref=worksheet.dimensions,displayName="Table" + str(i),tableStyleInfo=mediumStyle)
        worksheet.add_table(table)
        
        for col in worksheet.columns:
            worksheet.column_dimensions[col[0].column_letter].width = (len(str(col[0].value)) + 2) * 1.3
    
    writer.book.save(path)
    writer.book.close()
    writer.close()
    os.rename(path,os.path.join("Mapped Providers 7",os.path.splitext(os.path.basename(path))[0]+" Mapped"+os.path.splitext(path)[-1]))

# %%
# %%time
n = 1
for provider_path in get_providers_path():
    start_time = time.time()
    print("Started mapping " + os.path.basename(provider_path))
    result = files_mapping(provider_path)
    if len(result) > 0:
        print("Finished mapping " + os.path.basename(provider_path))
        export_excel(provider_path)
        print("Exported " + os.path.basename(provider_path) + " to the 'Mapped Providers 7' folder")
        elapsed_time = time.time() - start_time
        print("Time: " + str(time.strftime("%H:%M:%S", time.gmtime(elapsed_time))) + "\n")
    else:
        print("There is no mappings for this provider\n")
# Out:
# Started mapping Abeer Supreme Medical Center 2 ## 6212001674 @ 1285.xlsx
# Finished mapping Abeer Supreme Medical Center 2 ## 6212001674 @ 1285.xlsx
# Exported Abeer Supreme Medical Center 2 ## 6212001674 @ 1285.xlsx to the 'Mapped Providers 7' folder
# Time: 00:02:06
#
# Started mapping Adwaa Al-alami Medical Complex ## 6212000751 @ 8071.xlsx
# Finished mapping Adwaa Al-alami Medical Complex ## 6212000751 @ 8071.xlsx
# Exported Adwaa Al-alami Medical Complex ## 6212000751 @ 8071.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:24
#
# Started mapping Ahad General Hospital ## 6212001747 @ 9106.xlsx
# Finished mapping Ahad General Hospital ## 6212001747 @ 9106.xlsx
# Exported Ahad General Hospital ## 6212001747 @ 9106.xlsx to the 'Mapped Providers 7' folder
# Time: 00:08:36
#
# Started mapping Al Dawaa Medical Services Company ## 6212001835 @ 38857.xlsx
# There is no mappings for this provider
#
# Started mapping Al Falah Hospital ## 6212000272 @ 2442.xlsx
# Finished mapping Al Falah Hospital ## 6212000272 @ 2442.xlsx
# Exported Al Falah Hospital ## 6212000272 @ 2442.xlsx to the 'Mapped Providers 7' folder
# Time: 00:03:11
#
# Started mapping Al Genah Medical Polyclinic ## 6212000968 @ 7904.xlsx
# Finished mapping Al Genah Medical Polyclinic ## 6212000968 @ 7904.xlsx
# Exported Al Genah Medical Polyclinic ## 6212000968 @ 7904.xlsx to the 'Mapped Providers 7' folder
# Time: 00:02:21
#
# Started mapping Al Hammadi Hospital ## 6212000242 @ 5422.xlsx
# Finished mapping Al Hammadi Hospital ## 6212000242 @ 5422.xlsx
# Exported Al Hammadi Hospital ## 6212000242 @ 5422.xlsx to the 'Mapped Providers 7' folder
# Time: 00:06:40
#
# Started mapping Al Jazeera Hospital - Riyadh ## 6212000885 @ 1789.xlsx
# Finished mapping Al Jazeera Hospital - Riyadh ## 6212000885 @ 1789.xlsx
# Exported Al Jazeera Hospital - Riyadh ## 6212000885 @ 1789.xlsx to the 'Mapped Providers 7' folder
# Time: 00:02:44
#
# Started mapping Al Kholood Medical Complex ## 6212000204 @ 6882.xlsx
# Finished mapping Al Kholood Medical Complex ## 6212000204 @ 6882.xlsx
# Exported Al Kholood Medical Complex ## 6212000204 @ 6882.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:11
#
# Started mapping Al Mouwasat Hospital Riyadh ## 6212001665 @ 4972.xlsx
# Finished mapping Al Mouwasat Hospital Riyadh ## 6212001665 @ 4972.xlsx
# Exported Al Mouwasat Hospital Riyadh ## 6212001665 @ 4972.xlsx to the 'Mapped Providers 7' folder
# Time: 00:06:31
#
# Started mapping Al Nahda National Hospital ## 6212000211 @ 2898.xlsx
# Finished mapping Al Nahda National Hospital ## 6212000211 @ 2898.xlsx
# Exported Al Nahda National Hospital ## 6212000211 @ 2898.xlsx to the 'Mapped Providers 7' folder
# Time: 00:04:03
#
# Started mapping Al Quds Polyclinic ## 6212000165 @ 3858.xlsx
# Finished mapping Al Quds Polyclinic ## 6212000165 @ 3858.xlsx
# Exported Al Quds Polyclinic ## 6212000165 @ 3858.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:16
#
# Started mapping Al Salam General Medical Center ## 6212000135 @ 1377.xlsx
# Finished mapping Al Salam General Medical Center ## 6212000135 @ 1377.xlsx
# Exported Al Salam General Medical Center ## 6212000135 @ 1377.xlsx to the 'Mapped Providers 7' folder
# Time: 00:02:13
#
# Started mapping Al Shamael Polyclinic ## 6212001538 @ 617.xlsx
# Finished mapping Al Shamael Polyclinic ## 6212001538 @ 617.xlsx
# Exported Al Shamael Polyclinic ## 6212001538 @ 617.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:25
#
# Started mapping Al Watan Clinics ## 6212000706 @ 7119.xlsx
# Finished mapping Al Watan Clinics ## 6212000706 @ 7119.xlsx
# Exported Al Watan Clinics ## 6212000706 @ 7119.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:24
#
# Started mapping Al-khazan Medical Clinics ## 6212000031 @ 391.xlsx
# Finished mapping Al-khazan Medical Clinics ## 6212000031 @ 391.xlsx
# Exported Al-khazan Medical Clinics ## 6212000031 @ 391.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:04
#
# Started mapping Aviccenna Medical Complex ## 6212000042 @ 9856.xlsx
# Finished mapping Aviccenna Medical Complex ## 6212000042 @ 9856.xlsx
# Exported Aviccenna Medical Complex ## 6212000042 @ 9856.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:33
#
# Started mapping Badr Al Tamam Polyclinic ## 6212000349 @ 588.xlsx
# Finished mapping Badr Al Tamam Polyclinic ## 6212000349 @ 588.xlsx
# Exported Badr Al Tamam Polyclinic ## 6212000349 @ 588.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:22
#
# Started mapping Badruddin Medical Group (bawadi) ## 6212000172 @ 8310.xlsx
# Finished mapping Badruddin Medical Group (bawadi) ## 6212000172 @ 8310.xlsx
# Exported Badruddin Medical Group (bawadi) ## 6212000172 @ 8310.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:51
#
# Started mapping Balghsoon Polyclinic  ## 6212000700 @ 572.xlsx
# Finished mapping Balghsoon Polyclinic  ## 6212000700 @ 572.xlsx
# Exported Balghsoon Polyclinic  ## 6212000700 @ 572.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:19
#
# Started mapping Dallah Hospital ## 6212000318 @ 6844.xlsx
# Finished mapping Dallah Hospital ## 6212000318 @ 6844.xlsx
# Exported Dallah Hospital ## 6212000318 @ 6844.xlsx to the 'Mapped Providers 7' folder
# Time: 00:06:51
#
# Started mapping Dammam National Medical Complex ## 6212000621 @ 645.xlsx
# Finished mapping Dammam National Medical Complex ## 6212000621 @ 645.xlsx
# Exported Dammam National Medical Complex ## 6212000621 @ 645.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:24
#
# Started mapping Dr. Hassan Ghazzawi Hospital - Jeddah ## 6212000334 @ 952.xlsx
# Finished mapping Dr. Hassan Ghazzawi Hospital - Jeddah ## 6212000334 @ 952.xlsx
# Exported Dr. Hassan Ghazzawi Hospital - Jeddah ## 6212000334 @ 952.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:47
#
# Started mapping Dr. Suliman Al Habib - Al Olaya Branch ## 6212000480 @ 12473.xlsx
# Finished mapping Dr. Suliman Al Habib - Al Olaya Branch ## 6212000480 @ 12473.xlsx
# Exported Dr. Suliman Al Habib - Al Olaya Branch ## 6212000480 @ 12473.xlsx to the 'Mapped Providers 7' folder
# Time: 00:12:18
#
# Started mapping Faiha Medical Clinic ## 6212000103 @ 883.xlsx
# Finished mapping Faiha Medical Clinic ## 6212000103 @ 883.xlsx
# Exported Faiha Medical Clinic ## 6212000103 @ 883.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:25
#
# Started mapping Future Care Clinic (buraydah) ## 6212000138 @ 703.xlsx
# Finished mapping Future Care Clinic (buraydah) ## 6212000138 @ 703.xlsx
# Exported Future Care Clinic (buraydah) ## 6212000138 @ 703.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:27
#
# Started mapping Green Crescent Hospital ## 6212000060 @ 3577.xlsx
# Finished mapping Green Crescent Hospital ## 6212000060 @ 3577.xlsx
# Exported Green Crescent Hospital ## 6212000060 @ 3577.xlsx to the 'Mapped Providers 7' folder
# Time: 00:04:45
#
# Started mapping H.o.w. Medical Group - Al-murooj ## 6212000062 @ 764.xlsx
# Finished mapping H.o.w. Medical Group - Al-murooj ## 6212000062 @ 764.xlsx
# Exported H.o.w. Medical Group - Al-murooj ## 6212000062 @ 764.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:32
#
# Started mapping Hayat National Hospital - Qassim ## 6212000853 @ 3603.xlsx
# Finished mapping Hayat National Hospital - Qassim ## 6212000853 @ 3603.xlsx
# Exported Hayat National Hospital - Qassim ## 6212000853 @ 3603.xlsx to the 'Mapped Providers 7' folder
# Time: 00:04:44
#
# Started mapping Hiba Asia Polyclinic ## 6212000646 @ 6949.xlsx
# Finished mapping Hiba Asia Polyclinic ## 6212000646 @ 6949.xlsx
# Exported Hiba Asia Polyclinic ## 6212000646 @ 6949.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:17
#
# Started mapping Hiba Asia Polyclinic 2 Jeddah ## 6212000690 @ 6949.xlsx
# Finished mapping Hiba Asia Polyclinic 2 Jeddah ## 6212000690 @ 6949.xlsx
# Exported Hiba Asia Polyclinic 2 Jeddah ## 6212000690 @ 6949.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:16
#
# Started mapping Jeddah National Hospital ## 6212000297 @ 1652.xlsx
# Finished mapping Jeddah National Hospital ## 6212000297 @ 1652.xlsx
# Exported Jeddah National Hospital ## 6212000297 @ 1652.xlsx to the 'Mapped Providers 7' folder
# Time: 00:02:33
#
# Started mapping Maha Al Khamis-1 Al Nassem ## 6212000558 @ 365.xlsx
# There is no mappings for this provider
#
# Started mapping Mohammed Al Dossary Hospital ## 6212000782 @ 9677.xlsx
# Finished mapping Mohammed Al Dossary Hospital ## 6212000782 @ 9677.xlsx
# Exported Mohammed Al Dossary Hospital ## 6212000782 @ 9677.xlsx to the 'Mapped Providers 7' folder
# Time: 00:04:31
#
# Started mapping Obeid Specialized Hospital - Riyadh ## 6212000073 @ 4726.xlsx
# Finished mapping Obeid Specialized Hospital - Riyadh ## 6212000073 @ 4726.xlsx
# Exported Obeid Specialized Hospital - Riyadh ## 6212000073 @ 4726.xlsx to the 'Mapped Providers 7' folder
# Time: 00:05:20
#
# Started mapping Rabiah Hospital ## 6212000557 @ 2703.xlsx
# Finished mapping Rabiah Hospital ## 6212000557 @ 2703.xlsx
# Exported Rabiah Hospital ## 6212000557 @ 2703.xlsx to the 'Mapped Providers 7' folder
# Time: 00:03:42
#
# Started mapping Safa Makkah Polyclinic 1 ## 6212000106 @ 255.xlsx
# Finished mapping Safa Makkah Polyclinic 1 ## 6212000106 @ 255.xlsx
# Exported Safa Makkah Polyclinic 1 ## 6212000106 @ 255.xlsx to the 'Mapped Providers 7' folder
# Time: 00:00:57
#
# Started mapping Safa Makkah Polyclinic 2 ## 6212000086 @ 505.xlsx
# Finished mapping Safa Makkah Polyclinic 2 ## 6212000086 @ 505.xlsx
# Exported Safa Makkah Polyclinic 2 ## 6212000086 @ 505.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:14
#
# Started mapping Safa Medical Center - Dammam ## 6212000673 @ 543.xlsx
# Finished mapping Safa Medical Center - Dammam ## 6212000673 @ 543.xlsx
# Exported Safa Medical Center - Dammam ## 6212000673 @ 543.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:18
#
# Started mapping Saudi National Hospital ## 6212000338 @ 970.xlsx
# Finished mapping Saudi National Hospital ## 6212000338 @ 970.xlsx
# Exported Saudi National Hospital ## 6212000338 @ 970.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:48
#
# Started mapping Shifa Al Khobar Polyclinic ## 6212000600 @ 598.xlsx
# Finished mapping Shifa Al Khobar Polyclinic ## 6212000600 @ 598.xlsx
# Exported Shifa Al Khobar Polyclinic ## 6212000600 @ 598.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:21
#
# Started mapping Shifa Al-jazeera Polyclinic ## 6212000102 @ 613.xlsx
# Finished mapping Shifa Al-jazeera Polyclinic ## 6212000102 @ 613.xlsx
# Exported Shifa Al-jazeera Polyclinic ## 6212000102 @ 613.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:22
#
# Started mapping Shifa Buraydah Polyclinic ## 6212000141 @ 473.xlsx
# Finished mapping Shifa Buraydah Polyclinic ## 6212000141 @ 473.xlsx
# Exported Shifa Buraydah Polyclinic ## 6212000141 @ 473.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:12
#
# Started mapping Shifa Jeddah Polyclinic ## 6212000304 @ 5903.xlsx
# Finished mapping Shifa Jeddah Polyclinic ## 6212000304 @ 5903.xlsx
# Exported Shifa Jeddah Polyclinic ## 6212000304 @ 5903.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:42
#
# Started mapping Specialized Medical Center Hospital ## 6212000401 @ 4306.xlsx
# Finished mapping Specialized Medical Center Hospital ## 6212000401 @ 4306.xlsx
# Exported Specialized Medical Center Hospital ## 6212000401 @ 4306.xlsx to the 'Mapped Providers 7' folder
# Time: 00:05:42
#
# Started mapping Taj General Specialty Medical & Diagnostic Center ## 6212000900 @ 636.xlsx
# Finished mapping Taj General Specialty Medical & Diagnostic Center ## 6212000900 @ 636.xlsx
# Exported Taj General Specialty Medical & Diagnostic Center ## 6212000900 @ 636.xlsx to the 'Mapped Providers 7' folder
# Time: 00:01:23
#
# Started mapping United Pharmaceutical Companies ## 6212001911 @ 7636.xlsx
# Finished mapping United Pharmaceutical Companies ## 6212001911 @ 7636.xlsx
# Exported United Pharmaceutical Companies ## 6212001911 @ 7636.xlsx to the 'Mapped Providers 7' folder
# Time: 00:05:48
#
# Started mapping Wahat Al Shifa Medical Center - 2 ## 6212001925 @ 8073.xlsx
# Finished mapping Wahat Al Shifa Medical Center - 2 ## 6212001925 @ 8073.xlsx
# Exported Wahat Al Shifa Medical Center - 2 ## 6212001925 @ 8073.xlsx to the 'Mapped Providers 7' folder
# Time: 00:02:42
#
# Wall time: 2h 15min 13s
